# %%
# Import the required module from the fyers_apiv3 package
from fyers_apiv3 import fyersModel

# Replace these values with your actual API credentials
client_id = "OYTP8YTH2B-100"
secret_key = "JSM921NJGG"
redirect_uri = "https://myapi.fyers.in/dashboard"
response_type = "code"  
state = "sample_state"

# Create a session model with the provided credentials
session = fyersModel.SessionModel(
    client_id=client_id,
    secret_key=secret_key,
    redirect_uri=redirect_uri,
    response_type=response_type
)

# Generate the auth code using the session model
response = session.generate_authcode()

# Print the auth code received in the response
print(response)
# Out:
# https://api-t1.fyers.in/api/v3/generate-authcode?client_id=OYTP8YTH2B-100&redirect_uri=https%3A%2F%2Fmyapi.fyers.in%2Fdashboard&response_type=code&state=None

# %%
# auth_code=
from urllib.parse import urlparse, parse_qs
url = "https://myapi.fyers.in/dashboard?s=ok&code=200&auth_code=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....JxNWkQhShTV5lqDpQW5mmn2Dangk73HyM3Lh_SAhE1Q&state=None"
parsed = urlparse(url)
params = parse_qs(parsed.query)

auth_code = params["auth_code"][0]
print("Auth Code:", auth_code)
# Out:
# Auth Code: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....JxNWkQhShTV5lqDpQW5mmn2Dangk73HyM3Lh_SAhE1Q

# %%
# Import the required module from the fyers_apiv3 package
from fyers_apiv3 import fyersModel
import os
response_type = "code" 
grant_type = "authorization_code"  

# The authorization code received from Fyers after the user grants access

# Create a session object to handle the Fyers API authentication and token generation
session = fyersModel.SessionModel(
    client_id=client_id,
    secret_key=secret_key, 
    redirect_uri=redirect_uri, 
    response_type=response_type, 
    grant_type=grant_type
)

# Set the authorization code in the session object
session.set_token(auth_code)
response = session.generate_token()
access_token = response["access_token"]
from dotenv import set_key
set_key(".env", "FYERS_ACCESS_TOKEN", access_token)
print("Token saved:", access_token[:20], "...")
from fyers_apiv3 import fyersModel
fyers = fyersModel.FyersModel(client_id=client_id, is_async=False, token=access_token, log_path="")
response = fyers.get_profile()
print(response)
# Out:
# Token saved: eyJhbGciOiJIUzI1NiIs ...
# {'s': 'ok', 'code': 200, 'message': '', 'data': {'fy_id': 'DR02814', 'name': 'RAHUL MOHAN NAIK', 'image': None, 'display_name': None, 'pin_change_date': '11-06-2026 12:36:39', 'email_id': 'nxxxxxxxxxx1@gmail.com', 'pwd_change_date': '01-11-2021 12:06:07;61', 'PAN': 'BAxxxxxx8E', 'mobile_number': '95xxxxxx79', 'totp': True, 'pwd_to_expire': 90, 'ddpi_enabled': False, 'mtf_enabled': False}}

# %%
# Out:
# {'s': 'ok', 'code': 200, 'message': '', 'data': {'fy_id': 'DR02814', 'name': 'RAHUL MOHAN NAIK', 'image': None, 'display_name': None, 'pin_change_date': '11-06-2026 12:36:39', 'email_id': 'nxxxxxxxxxx1@gmail.com', 'pwd_change_date': '01-11-2021 12:06:07;61', 'PAN': 'BAxxxxxx8E', 'mobile_number': '95xxxxxx79', 'totp': True, 'pwd_to_expire': 90, 'ddpi_enabled': False, 'mtf_enabled': False}}
